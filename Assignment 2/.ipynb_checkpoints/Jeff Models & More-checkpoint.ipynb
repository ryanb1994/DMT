# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train3.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
y = pd.read_csv('target3.csv')
# df = df[0:100000]
# y = df[0:100000]
X = df.drop(['click_bool', 'booking_bool', 'position'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
# y_train = y_train.drop('Unnamed: 0', axis = 1)
# y_test = y_test.drop('Unnamed: 0', axis = 1)

# %%
df = pd.read_csv('train3.csv')
df = df.drop(['Unnamed: 0', 'click_bool', 'booking_bool', 'position'], axis = 1)
y = pd.read_csv('target3.csv')
y = y.drop(['Unnamed: 0'], axis = 1)

# %%
print df.columns
print y.columns
# Out:
# Index([u'srch_id', u'prop_country_id', u'year', u'month', u'prop_score',
#        u'prop_location_score1', u'prop_location_score2', u'diff_hist_price',
#        u'usd_diff', u'prop_id', u'star_diff', u'srch_query_affinity_score',
#        u'orig_destination_distance', u'prop_brand_bool', u'prop_review_score',
#        u'price_rank', u'stars_rank', u'score_rank', u'price_per_pers',
#        u'random_bool', u'price_usd', u'total_price', u'nr_pers',
#        u'prop_id_counts', u'comp2_rate', u'comp5_rate', u'comp8_rate'],
#       dtype='object')
# Index([u'position', u'rank_rel'], dtype='object')

# %%
X_train = df[:3500000]
y_train = y[:3500000]
X_test = df[3500001:]
y_test = y[3500001:]

# %%
print X_train.shape
print y_train.shape
print X_test.shape
print y_test.shape
# Out:
# (3500000, 27)
# (3500000, 2)
# (1458346, 27)
# (1458346, 2)

# %% [markdown]
# MLP

# %%
scaler = StandardScaler()  
scaler.fit(X_train)
X_trainmlp = scaler.transform(X_train)  
X_testmlp = scaler.transform(X_test)

# %%
mlp = MLPRegressor(hidden_layer_sizes=(100,55,55))
mlp.fit(X_trainmlp,y_train)
mlp_pred = mlp.predict(X_testmlp)
print mlp.score(X_testmlp, y_test)
# Out:
# 0.2712448401803325

# %%
print accuracy_score(y_test,mlp_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-94c8ee4d5367> in <module>()
# ----> 1 print accuracy_score(y_test,mlp_pred)
#
# NameError: name 'accuracy_score' is not defined

# %%
mlptraindatapredicion = mlp.predict
# Out:
#                  0         1
# 0        20.559498  0.261825
# 1        20.432689  0.174894
# 2        26.080438  0.099847
# 3        24.524518  0.048277
# 4         5.813314  0.501515
# 5         9.014809  0.463159
# 6        26.161256  0.054669
# 7         6.720619  0.635753
# 8        20.539376  0.260328
# 9        18.304063 -0.029798
# 10       14.114909  0.210775
# 11       24.196095 -0.000698
# 12       19.212163  0.059100
# 13       22.282423  0.007459
# 14       16.979783  0.128812
# 15       17.374537  0.125161
# 16       17.339863  0.138693
# 17       16.206027  0.113573
# 18       19.456724  0.098216
# 19       16.771560  0.130829
# 20       17.884862  0.071237
# 21       16.656688  0.100950
# 22       17.912648  0.111747
# 23       19.339226  0.033056
# 24       19.350310  0.112870
# 25       16.159955  0.181911
# 26       18.243797  0.071606
# 27       20.580343  0.011238
# 28       14.766984  0.197793
# 29       16.886656  0.125086
# ...            ...       ...
# 1458316  21.478151  0.446216
# 1458317  16.758062  0.405237
# 1458318  14.627945  0.201370
# 1458319  20.858867  0.404700
# 1458320  17.464023  0.188595
# 1458321  18.706669  0.107968
# 1458322   7.571629  0.397587
# 1458323  16.417799  0.452162
# 1458324   6.809880  0.538852
# 1458325  22.100049  0.016009
# 1458326  16.485472  0.461179
# 1458327  20.637144  0.166409
# 1458328   6.603203  0.426714
# 1458329  17.539230  0.226666
# 1458330  18.248150  0.131943
# 1458331  20.303246  0.233378
# 1458332  25.574500  0.058818
# 1458333  25.026731  0.046256
# 1458334  15.580364  0.137302
# 1458335  19.662275  0.322508
# 1458336  18.030110  0.255534
# 1458337  16.619960  0.631099
# 1458338  20.237244  0.205051
# 1458339  11.422877  0.254971
# 1458340  11.815109  0.282257
# 1458341   4.913713  0.403956
# 1458342   3.385910  0.680965
# 1458343  10.024344  0.296567
# 1458344   5.904752  0.466270
# 1458345  13.541683  0.293017
#
# [1458346 rows x 2 columns]

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
from sklearn.externals import joblib
s = joblib.dump(mlp, 'mlpmodel.pkl')

# %%
mlp = joblib.load('mlpwholedataset.pkl')

# %%
df = pd.read_csv('train3.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
X = df.drop(['click_bool', 'booking_bool', 'position'],axis=1)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)
scaler = StandardScaler()  
scaler.fit(X_train)
X_wholetrain = scaler.transform(X)

# %%
print mlp.score(X_wholetrain,y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-69-3d1e4bde725a> in <module>()
# ----> 1 print mlp.score(X_wholetrain,y)
#
# C:\Users\Jeffr\Miniconda3\envs\python2\lib\site-packages\sklearn\base.pyc in score(self, X, y, sample_weight)
#     384
#     385         from .metrics import r2_score
# --> 386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     387                         multioutput='variance_weighted')
#     388
#
# C:\Users\Jeffr\Miniconda3\envs\python2\lib\site-packages\sklearn\neural_network\multilayer_perceptron.pyc in predict(self, X)
#    1295         """
#    1296         check_is_fitted(self, "coefs_")
# -> 1297         y_pred = self._predict(X)
#    1298         if y_pred.shape[1] == 1:
#    1299             return y_pred.ravel()
#
# C:\Users\Jeffr\Miniconda3\envs\python2\lib\site-packages\sklearn\neural_network\multilayer_perceptron.pyc in _predict(self, X)
#     674         for i in range(self.n_layers_ - 1):
#     675             activations.append(np.empty((X.shape[0],
# --> 676                                          layer_units[i + 1])))
#     677         # forward propagate
#     678         self._forward_pass(activations)
#
# MemoryError:

# %% [markdown]
# So we have a model. Let it use all the data of the dataframe to predict position. Then use that prediction to use in ensemble, when we have three prediction of the whole dataframe in one file, we can further

# %%
pd.DataFrame(X_wholetrain)
# Out:
#                0         1         2         3         4         5         6   \
# 0       -1.730951  0.658804  0.495043 -0.333444 -0.068569 -0.027817 -0.383935
# 1       -1.730951  0.658804  0.495043 -0.333444 -0.068574 -0.439310 -0.575527
# 2       -1.730951  0.658804  0.495043 -0.333444 -0.068571 -0.439310 -0.511884
# 3       -1.730951  0.658804  0.495043 -0.333444 -0.068576 -0.027817 -0.591438
# 4       -1.730951  0.658804  0.495043 -0.333444 -0.068547 -0.151918  0.148412
# 5       -1.730951  0.658804  0.495043 -0.333444 -0.068547 -0.067007  0.188852
# 6       -1.730951  0.658804  0.495043 -0.333444 -0.068568 -0.439310 -0.438297
# 7       -1.730951  0.658804  0.495043 -0.333444 -0.068579 -0.824676 -0.674306
# 8       -1.730951  0.658804  0.495043 -0.333444 -0.068547 -0.204171  0.146424
# 23       0.003664 -0.007688  0.930630    ...     0.721723 -0.016313  1.542568
# 24       0.004514 -0.004374  1.007656    ...     0.023908 -0.014079  1.542568
# 25       0.005519 -0.008174  1.010266    ...    -0.673907 -0.016641  1.542568
# 26       0.006489 -0.009144  1.100392    ...    -0.773595 -0.017294  1.542568
# 27       0.009178 -0.003808  1.299309    ...    -0.972971 -0.013698  1.542568
# 28       0.012646  0.002745 -1.636403    ...     0.821411  0.028008  1.542568
# 29       0.005273  0.002995 -1.439480    ...    -1.172347  0.028682  1.542568
# ...           ...       ...       ...    ...          ...       ...       ...
# 4958317 -0.001780 -0.007480 -1.204858    ...     1.220162  0.000435 -0.648270
# 4958318 -0.002632 -0.006628 -1.104562    ...     0.123595  0.002732 -0.648270
# 4958319 -0.002632 -0.006628 -1.012959    ...    -0.374844  0.002732 -0.648270
# 4958320 -0.003915 -0.005344 -0.952924    ...     0.322971  0.006193 -0.648270
# 4958321 -0.001415 -0.007845 -0.864645    ...     0.522347 -0.000550 -0.648270
# 4958322 -0.006890 -0.002370 -0.538370    ...    -0.773595  0.014214 -0.648270
# 4958323 -0.006282 -0.002978 -0.531082    ...     1.120474  0.012574 -0.648270
# 4958324 -0.012972  0.003712 -0.490722    ...     0.422659  0.030617 -0.648270
# 4958325 -0.005673 -0.003586 -0.456149    ...     1.419538  0.010934 -0.648270
# 4958326 -0.007802 -0.001458 -0.455410    ...    -1.072659  0.016674 -0.648270
# 4958327 -0.004760 -0.004500 -0.453736    ...     0.622035  0.008472 -0.648270
# 4958328 -0.008410 -0.000850 -0.433790    ...    -0.873283  0.018314 -0.648270
# 4958329 -0.006586 -0.002674 -0.367427    ...     0.721723  0.013395 -0.648270
# 4958330 -0.009931  0.000671 -0.297075    ...     0.921098  0.022416 -0.648270
# 4958331  0.002478 -0.011738  0.199257    ...    -1.172347 -0.011047 -0.648270
# 4958332  0.000640 -0.009900  0.294800    ...    -0.275156 -0.006093 -0.648270
# 4958333 -0.000503 -0.008757  0.448851    ...     0.023908 -0.003010 -0.648270
# 4958334  0.000464 -0.009724  0.485665    ...    -0.474532 -0.005617 -0.648270
# 4958335 -0.006890 -0.002370  0.506916    ...     1.020786  0.014214 -0.648270
# 4958336 -0.012364  0.003104  1.085888    ...     0.223283  0.028975 -0.648270
# 4958337 -0.006890 -0.002370  1.119993    ...    -0.574220  0.014214 -0.648270
# 4958338 -0.005685 -0.003575  1.260673    ...    -0.972971  0.010964 -0.648270
# 4958339 -0.000259 -0.009001  1.442944    ...     0.821411 -0.003668 -0.648270
# 4958340 -0.000238 -0.009022  1.729253    ...     1.519226 -0.003723 -0.648270
# 4958341 -0.000381 -0.008879 -0.368609    ...    -1.172347 -0.015585 -0.648270
# 4958342 -0.000943 -0.008317  0.187659    ...    -0.873283 -0.015080 -0.648270
# 4958343  0.000869 -0.010129  0.443336    ...    -0.673907 -0.016709 -0.648270
# 4958344  0.000244 -0.009504  0.601548    ...    -0.972971 -0.016147 -0.648270
# 4958345 -0.002256 -0.007004  1.435138    ...    -0.773595 -0.013900 -0.648270
# 4958346  0.002619 -0.011879  1.597389    ...    -1.172347 -0.018282 -0.648270
#
#                20        21        22        23        24        25        26
# 4958323 -0.003174 -0.004606 -1.121229  0.955612 -0.062791 -0.029081  0.080288
# 4958324  0.003517  0.002041 -1.121229 -0.136567 -0.062791 -0.029081  0.080288
# 4958325 -0.003782 -0.005210 -1.121229  0.971487 -3.542627 -0.029081  0.080288
# 4958326 -0.001654 -0.003096 -1.121229 -0.212766 -0.062791 -0.029081  0.080288
# 4958327 -0.004695 -0.006117 -1.121229  0.701617 -0.062791 -0.029081  0.080288
# 4958328 -0.001046 -0.002491 -1.121229  0.111078 -3.542627 -2.890393  0.080288
# 4958329 -0.002870 -0.004304 -1.121229  0.755591 -0.062791 -0.029081  0.080288
# 4958330  0.000476 -0.000980 -1.121229  0.685742 -3.542627 -2.890393  0.080288
# 4958331 -0.011933 -0.013308 -1.121229 -0.222291 -0.062791 -0.029081  0.080288
# 4958332 -0.010096 -0.011482 -1.121229  0.349199  3.417044  2.832230  3.490894
# 4958333 -0.008953 -0.010347 -1.121229  0.301574 -0.062791 -0.029081  0.080288
# 4958334 -0.009920 -0.011307 -1.121229 -0.174666 -0.062791 -0.029081  0.080288
# 4958335 -0.002566 -0.004002 -1.121229  0.854014 -0.062791 -0.029081  0.080288
# 4958336  0.002908  0.001436 -1.121229  0.993711 -0.062791 -2.890393 -3.330318
# 4958337 -0.002566 -0.004002 -1.121229  0.215851 -0.062791 -0.029081  0.080288
# 4958338 -0.003771 -0.005199 -1.121229  0.612719 -0.062791 -0.029081  0.080288
# 4958339 -0.009197 -0.010589 -1.121229  0.526995 -0.062791  2.832230  0.080288
# 4958340 -0.009217 -0.010609 -1.121229  0.768291 -0.062791 -0.029081  0.080288
# 4958341 -0.009075 -0.010468  0.573585 -0.587409 -0.062791 -0.029081  0.080288
# 4958342 -0.008512 -0.009909  0.573585 -0.527085 -0.062791 -0.029081  0.080288
# 4958343 -0.010325 -0.011710  0.573585 -0.555659 -0.062791 -0.029081  0.080288
# 4958344 -0.009700 -0.011089  0.573585 -0.539784 -0.062791 -0.029081  0.080288
# 4958345 -0.007200 -0.008605  0.573585 -0.558834 -0.062791 -0.029081  0.080288
# 4958346 -0.012075 -0.013448  0.573585 -0.638208 -0.062791 -0.029081  0.080288
#
# [4958347 rows x 27 columns]

# %%
pred = mlp.predict(X)

# %%
pd.DataFrame(pred)

# %%
predinverse =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-ec995e8032b3> in <module>()
# ----> 1 pred.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
testfile = pd.read_csv('test2.csv')

# %%
X_t = scaler.transform(testfile)

# %%
testtarget = mlp.predict(X_t)

# %%
testtarget = pd.DataFrame(testtarget)

# %%
testtarget[0].to_csv('outputwholetestsetmlp.csv')

# %%
testfile.columns

# %%
pd.DataFrame(y_train)

# %%
pd.DataFrame(testtarget)

# %%
testfile = testfile.join(pd.DataFrame(testtarget))

# %%
testfile2 = testfile.groupby('srch_id')[0].apply(lambda x: x.sort_values(ascending=False))

# %%
testfile2.head(25)

# %%
testfile3 = testfile.groupby(['srch_id', 'prop_id'])[0].nlargest(100)
# df.sort_values(['job','count'],ascending=False).groupby('job').head(3)

# %%
testfile3 = testfile3.reset_index()

# %%
testfile3 = testfile3.drop('level_1', axis=1)

# %%
testfile3.columns

# %%
testfile3
